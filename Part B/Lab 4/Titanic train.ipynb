# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv(r"E:\ISE 5th Sem\Lab\Part - B\4\train.csv")
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.head(5)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.drop(['PassengerId','Name','Parch','Ticket'],axis=1,inplace=True)
df.head(5)
# Out:
#    Survived  Pclass     Sex   Age  SibSp     Fare Cabin Embarked
# 0         0       3    male  22.0      1   7.2500   NaN        S
# 1         1       1  female  38.0      1  71.2833   C85        C
# 2         1       3  female  26.0      0   7.9250   NaN        S
# 3         1       1  female  35.0      1  53.1000  C123        S
# 4         0       3    male  35.0      0   8.0500   NaN        S

# %%
df['Survived']=df['Survived'].map({
    0:'Died',
    1:'Survived'
})
df.head(5)
# Out:
#    Survived  Pclass     Sex   Age  SibSp     Fare Cabin Embarked
# 0      Died       3    male  22.0      1   7.2500   NaN        S
# 1  Survived       1  female  38.0      1  71.2833   C85        C
# 2  Survived       3  female  26.0      0   7.9250   NaN        S
# 3  Survived       1  female  35.0      1  53.1000  C123        S
# 4      Died       3    male  35.0      0   8.0500   NaN        S

# %%
df['Pclass']=df['Pclass'].map({
    1:'Luxuary class',
    2:'Economy class',
    3:'Lower class'
})
df.head(5)
# Out:
#    Survived         Pclass     Sex   Age  SibSp     Fare Cabin Embarked
# 0      Died    Lower class    male  22.0      1   7.2500   NaN        S
# 1  Survived  Luxuary class  female  38.0      1  71.2833   C85        C
# 2  Survived    Lower class  female  26.0      0   7.9250   NaN        S
# 3  Survived  Luxuary class  female  35.0      1  53.1000  C123        S
# 4      Died    Lower class    male  35.0      0   8.0500   NaN        S

# %%
df.drop(['Cabin','Fare'],axis=1,inplace=True)
df.head(5)
# Out:
#    Survived         Pclass     Sex   Age  SibSp Embarked
# 0      Died    Lower class    male  22.0      1        S
# 1  Survived  Luxuary class  female  38.0      1        C
# 2  Survived    Lower class  female  26.0      0        S
# 3  Survived  Luxuary class  female  35.0      1        S
# 4      Died    Lower class    male  35.0      0        S

# %%
df['Embarked']=df['Embarked'].map({
    'C':'Chersbourg',
    'Q':'Queenstown',
    'S':'Southampton'
})
df.head(5)
# Out:
#    Survived         Pclass     Sex   Age  SibSp     Embarked
# 0      Died    Lower class    male  22.0      1  Southampton
# 1  Survived  Luxuary class  female  38.0      1   Chersbourg
# 2  Survived    Lower class  female  26.0      0  Southampton
# 3  Survived  Luxuary class  female  35.0      1  Southampton
# 4      Died    Lower class    male  35.0      0  Southampton

# %%
ax=sns.countplot(x='Pclass',hue='Survived',palette='Set1',data=df)
ax.set(title='Passenger status against Passenger class',xlabel='Pclass',ylabel='Total')
plt.show()

# %%
ax=sns.countplot(x='Sex',hue='Survived',palette='Set2',data=df)
ax.set(title='survived against sex',xlabel='Sex',ylabel='Total')
plt.show()

# %%
ax=sns.countplot(x='Embarked',hue='Survived',palette='Set1',data=df)
ax.set(title='survived distribution acc emabarked port ',ylabel='Total')
plt.show()

# %%
intervals=(0,18,35,50,120)
categories=['Children','Teens','Adults','Old']
df['age_cats']=pd.cut(df.Age,intervals,labels=categories)

# %%
ax=sns.countplot(x='age_cats',hue='Survived',palette='Set1',data=df)
ax.set(title='survived distribution acc to age categories',xlabel='age_categories',ylabel='total')
plt.show()
